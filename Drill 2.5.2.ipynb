# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df = pd.read_csv('crime.csv', delimiter= ',', header=0)

# %%
df.head(2)
# Out:
#                        City  Population  Violent\ncrime  \
# 0             Adams Village        1851               0
# 1  Addison Town and Village        2568               2
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                       0                           NaN
# 1                                       0                           NaN
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          0.0        0                    0             11.0
# 1                          0.0        1                    1             49.0
#
#    Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3
# 0         1             10.0                      0     0.0
# 1         1             47.0                      1     0.0

# %%
df.shape
# Out:
# (348, 13)

# %%
#Check null
df.isna().sum()
# Out:
# City                                      0
# Population                                0
# Violent crime                             0
# Murder and nonnegligent manslaughter      0
# Rape (revised definition)1              348
# Rape (legacy definition)2                 0
# Robbery                                   0
# Aggravated assault                        0
# Property crime                            0
# Burglary                                  0
# Larceny-theft                             0
# Motor vehicle theft                       0
# Arson3                                  161
# dtype: int64

# %%
df = df.drop('Rape (revised definition)1',axis=1)

# %%
#check data type
df.dtypes
# Out:
# City                                     object
# Population                                int64
# Violent crime                             int64
# Murder and nonnegligent manslaughter      int64
# Rape (legacy definition)2                 int64
# Robbery                                   int64
# Aggravated assault                        int64
# Property crime                            int64
# Burglary                                  int64
# Larceny-theft                             int64
# Motor vehicle theft                       int64
# Arson3                                  float64
# dtype: object

# %%
df.describe()
# Out:
#          Population  Violent crime  Murder and nonnegligent manslaughter  \
# count  3.480000e+02     348.000000                            348.000000
# mean   4.003763e+04     201.594828                              1.566092
# std    4.500374e+05    2815.268504                             18.303673
# min    5.260000e+02       0.000000                              0.000000
# 25%    3.003000e+03       2.000000                              0.000000
# 50%    7.233500e+03       6.000000                              0.000000
# 75%    1.842750e+04      22.000000                              0.000000
# max    8.396126e+06   52384.000000                            335.000000
#
#        Rape (legacy definition)2       Robbery  Aggravated assault  \
# count                 348.000000    348.000000          348.000000
# mean                    5.864943     72.902299          121.261494
# std                    60.425452   1031.032873         1706.131730
# min                     0.000000      0.000000            0.000000
# 25%                     0.000000      0.000000            1.000000
# 50%                     0.000000      1.000000            4.000000
# 75%                     2.000000      5.000000           14.000000
# max                  1112.000000  19170.000000        31767.000000
#
#        Property crime      Burglary  Larceny-theft  Motor vehicle theft  \
# count      348.000000    348.000000     348.000000           348.000000
# mean       792.606322    119.683908     637.017241            35.905172
# std       7659.724746    924.948789    6346.054451           403.423826
# min          0.000000      0.000000       0.000000             0.000000
# 25%         40.500000      6.000000      31.000000             0.000000
# 50%        112.500000     17.500000      94.000000             2.000000
# 75%        341.000000     51.250000     287.250000             7.000000
# max     141971.000000  16606.000000  117931.000000          7434.000000
#
#            Arson3
# count  187.000000
# mean     1.871658
# std     10.693411
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max    132.000000

# %%
check=['Population','Violent crime','Murder and nonnegligent manslaughter','Rape (legacy definition)2','Robbery','Aggravated assault','Property crime',
      'Burglary','Larceny-theft','Motor vehicle theft','Arson3']
plt.figure(figsize=(15, 15))
counter=1

for i in check:
    plt.subplot(4,3,counter)
    plt.boxplot(test[i], 0, 'rs', 0)
    plt.title(i)
    counter+=1
plt.show()
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1857: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1864: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1872: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1873: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)

# %%
# check the outlier
df = df.sort_values(by='Population', ascending=False)
df.head(5)
# Out:
#           City  Population  Violent crime  \
# 216   New York     8396126          52384
# 35     Buffalo      258789           3249
# 272  Rochester      210562           2107
# 346    Yonkers      199134           1036
# 310   Syracuse      143834           1192
#
#      Murder and nonnegligent manslaughter  Rape (legacy definition)2  Robbery  \
# 216                                   335                       1112    19170
# 35                                     47                        145     1322
# 272                                    42                         92      918
# 346                                     6                         25      390
# 310                                    21                         75      400
#
#      Aggravated assault  Property crime  Burglary  Larceny-theft  \
# 216               31767          141971     16606         117931
# 35                 1735           12491      3458           8076
# 272                1055           10051      2587           6855
# 346                 615            2368       470           1662
# 310                 696            6473      1781           4298
#
#      Motor vehicle theft  Arson3
# 216                 7434     NaN
# 35                   957     NaN
# 272                  609   132.0
# 346                  236    10.0
# 310                  394    57.0

# %%
# new york is a outlier 
df = df[df['City'] != 'New York']

# %%
df = df.sort_values(by='Population', ascending=False)
df.head(5)
# Out:
#              City  Population  Violent crime  \
# 35        Buffalo      258789           3249
# 272     Rochester      210562           2107
# 346       Yonkers      199134           1036
# 310      Syracuse      143834           1192
# 7    Amherst Town      118296            107
#
#      Murder and nonnegligent manslaughter  Rape (legacy definition)2  Robbery  \
# 35                                     47                        145     1322
# 272                                    42                         92      918
# 346                                     6                         25      390
# 310                                    21                         75      400
# 7                                       1                          7       31
#
#      Aggravated assault  Property crime  Burglary  Larceny-theft  \
# 35                 1735           12491      3458           8076
# 272                1055           10051      2587           6855
# 346                 615            2368       470           1662
# 310                 696            6473      1781           4298
# 7                    68            2118       204           1882
#
#      Motor vehicle theft  Arson3
# 35                   957     NaN
# 272                  609   132.0
# 346                  236    10.0
# 310                  394    57.0
# 7                     32     3.0

# %%
test=df
test = test.iloc[:,1:]

plt.figure(figsize=(15, 14))
counter=1

for i in check:
    plt.subplot(4,3,counter)
    plt.boxplot(test[i], 0, 'rs', 0)
    plt.title(i)
    counter+=1
plt.show()
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1857: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1864: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1872: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1873: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)

# %%
df=test

# %%
df['Arson3'].unique()
#df.groupby('Arson3').count()
# Out:
# array([  nan,  132.,   10.,   57.,    3.,    2.,    1.,    5.,   22.,
#           6.,    0.,    8.,    4.,   15.])

# %%
# convert Murder , Robbery to float
df['Robbery']=df['Robbery'] *1.
df['Murder and nonnegligent manslaughter']=df['Murder and nonnegligent manslaughter'] *1.

# %%
#check data type
df.dtypes
# Out:
# Population                                int64
# Violent crime                             int64
# Murder and nonnegligent manslaughter    float64
# Rape (legacy definition)2                 int64
# Robbery                                 float64
# Aggravated assault                        int64
# Property crime                            int64
# Burglary                                  int64
# Larceny-theft                             int64
# Motor vehicle theft                       int64
# Arson3                                  float64
# dtype: object

# %%
#Assign feature
#     Propertycrime=α+Population+Population2+Murder+Robbery

feature = pd.DataFrame()
feature['Murder and nonnegligent manslaughter'] =df['Murder and nonnegligent manslaughter']
feature['Population']= df['Population']
feature['Robbery']= df['Robbery']
feature['Population2']= np.power(df['Population'],2)

target = df['Property crime']

# %%
# Run simple regression
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(feature, target)
print('\nValues Coefficients: \n', regr.coef_)
print('\nValues Intercept: \n', regr.intercept_)
print('\nValues R-squared:')
print(regr.score(feature, target))
# Out:
# Values Coefficients:
#  [  1.02643383e+02   2.05519792e-02   5.13001360e+00  -7.19468320e-08]
#
# Values Intercept:
#  -25.0398582081
#
# Values R-squared:
# 0.939283140822

# %%
# Run multiple regression
import statsmodels.formula.api as smf
linear_formula = "'Property crime' ~ 'Robbery'+'Murder and nonnegligent manslaughter'+'Population'+'Population2'"

lm = smf.ols(formula=linear_formula, data=df).fit()

#linear_formula = "Property crime ~Robbery+Murder and nonnegligent manslaughter+Population+Population2"

print ('Coefficient:  ')
print (lm.params)

print ('\nP-Value:  ')
print (lm.pvalues)

print ('\nR-Squared:   ')
print (lm.rsquared)

print ('\nConfidence Intervals:   ')
print (lm.conf_int())
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-134-15221fe487b5> in <module>()
#       3 linear_formula = "'Property crime' ~ 'Robbery'+'Murder and nonnegligent manslaughter'+'Population'+'Population2'"
#       4
# ----> 5 lm = smf.ols(formula=linear_formula, data=df).fit()
#       6
#       7 #linear_formula = "Property crime ~Robbery+Murder and nonnegligent manslaughter+Population+Population2"
#
# /home/ll/anaconda3/lib/python3.5/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /home/ll/anaconda3/lib/python3.5/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /home/ll/anaconda3/lib/python3.5/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /home/ll/anaconda3/lib/python3.5/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167         return build_design_matrices(design_infos, data,
#     168                                      NA_action=NA_action,
# --> 169                                      return_type=return_type)
#     170     else:
#     171         # No builders, but maybe we can still get matrices
#
# /home/ll/anaconda3/lib/python3.5/site-packages/patsy/build.py in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     891                 name = factor_info.factor.name()
#     892                 origin = factor_info.factor.origin
# --> 893                 rows_checker.check(value.shape[0], name, origin)
#     894                 if (have_pandas
#     895                     and isinstance(value, (pandas.Series, pandas.DataFrame))):
#
# /home/ll/anaconda3/lib/python3.5/site-packages/patsy/build.py in check(self, seen_value, desc, origin)
#     793                 # XX FIXME: this is a case where having discontiguous Origins
#     794                 # would be useful...
# --> 795                 raise PatsyError(msg, origin)
#     796
#     797 def build_design_matrices(design_infos, data,
#
# PatsyError: Number of rows mismatch between data argument and 'Property crime' (347 versus 1)
#     'Property crime' ~ 'Robbery'+'Murder and nonnegligent manslaughter'+'Population'+'Population2'
#     ^^^^^^^^^^^^^^^^

# %%
# Check whether linear relationship
#feature2 =df.drop(['Property crime'],axis=1)
feature2 = df

plt.figure(figsize=(20, 50))
counter=1

for i in check:
    plt.subplot(8,2,counter)
    sns.regplot(feature2[i], feature2['Property crime'], ci = False)
    plt.title(i)
    counter+=1
plt.show()

# %% [markdown]
# ### drop 3 more outliers from population

# %%
feature2 = df[df['Population']<=130000]
plt.figure(figsize=(20, 50))
counter=1
lenth=len(check)
for i in check:
    plt.subplot(lenth,2,counter)
    sns.regplot(feature2[i], feature2['Property crime'], ci = False)
    counter +=1
    plt.subplot(lenth,2,counter)
    plt.hist(feature2[i])
    plt.title(i)
    counter+=1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-42022fff9912> in <module>()
#       8     counter +=1
#       9     plt.subplot(lenth,2,counter)
# ---> 10     plt.hist(feature2[i])
#      11     plt.title(i)
#      12     counter+=1
#
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3002                       histtype=histtype, align=align, orientation=orientation,
#    3003                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3004                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3005     finally:
#    3006         ax._hold = washold
#
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6205             # this will automatically overwrite bins,
#    6206             # so that each histogram uses the same bins
# -> 6207             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6208             m = m.astype(float)  # causes problems later if it's an int
#    6209             if mlast is None:
#
# /home/ll/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     665     if mn > mx:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([mn, mx])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
# Check target distribution
plt.hist(feature2['Property crime'])
plt.show()

# %%
feature2['Property crime'] = np.sqrt(feature2['Property crime'])
plt.hist(feature2['Property crime'])
plt.show()
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
from sklearn.preprocessing import MinMaxScaler
check2=['Population','Violent crime','Murder and nonnegligent manslaughter','Rape (legacy definition)2','Robbery','Aggravated assault','Property crime',
      'Burglary','Larceny-theft','Motor vehicle theft']
scaler = MinMaxScaler()
feature2[check2] = scaler.fit_transform(feature2[check2])
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ll/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
feature2.head(5)
# Out:
#      Population  Violent crime  Murder and nonnegligent manslaughter  \
# 7      1.000000       0.135272                                   0.1
# 3      0.827290       1.000000                                   0.8
# 126    0.816345       0.190898                                   0.0
# 267    0.735994       0.072061                                   0.2
# 57     0.680810       0.082174                                   0.0
#
#      Rape (legacy definition)2   Robbery  Aggravated assault  Property crime  \
# 7                     0.225806  0.135965            0.129278        0.719617
# 3                     0.967742  0.995614            1.000000        1.000000
# 126                   0.290323  0.263158            0.155894        0.750387
# 267                   0.161290  0.039474            0.077947        0.372332
# 57                    0.258065  0.074561            0.076046        0.608618
#
#      Burglary  Larceny-theft  Motor vehicle theft  Arson3
# 7    0.265280       0.580327             0.209150     3.0
# 3    0.916775       1.000000             0.928105     NaN
# 126  0.431730       0.593586             0.300654     NaN
# 267  0.114434       0.143694             0.084967     NaN
# 57   0.128739       0.427999             0.183007     NaN

# %%
plt.figure(figsize=(20, 50))
counter=1
lenth=len(check2)
for i in check2:
    plt.subplot(lenth,2,counter)
    sns.regplot(feature2[i], feature2['Property crime'], ci = False)
    counter +=1
    plt.subplot(lenth,2,counter)
    plt.hist(feature2[i])
    plt.title(i)
    counter+=1
plt.show()

# %%
regr = linear_model.LinearRegression()
#target = feature2['Property crime'].values.reshape(-1, 1)
feature2 = feature2[['Population','Violent crime','Murder and nonnegligent manslaughter','Rape (legacy definition)2','Robbery','Aggravated assault',
      'Burglary','Larceny-theft','Motor vehicle theft']]

regr.fit(feature2, target)

print('\nCoefficients: \n', regr.coef_)
print('\nIntercept: \n', regr.intercept_)
print('\nR-squared:')
print(regr.score(feature2,target))
# Out:
# Coefficients:
#  [ 0.22197978 -0.20768306 -0.00680246  0.1416918   0.27321362 -0.43896279
#   0.30640544  0.87478953 -0.02743365]
#
# Intercept:
#  0.109536737795
#
# R-squared:
# 0.901220605259

# %%
_ = sns.pairplot(feature2)

# %% [markdown]
# ## Validate with new data

# %%
newdf = pd.read_csv('crimenew.csv', delimiter= ',', header=0)

# %%
newdf.dtypes
# Out:
# City                                     object
# Population                                int64
# Violent crime                             int64
# Murder and nonnegligent manslaughter      int64
# Rape (revised definition)1              float64
# Rape (legacy definition)2               float64
# Robbery                                   int64
# Aggravated assault                        int64
# Property crime                          float64
# Burglary                                  int64
# Larceny-theft                           float64
# Motor vehicle theft                       int64
# Arson3                                  float64
# dtype: object

# %%
newdf.head(4)
# Out:
#                        City  Population  Violent crime  \
# 0             Adams Village        1851              0
# 1  Addison Town and Village        2568              2
# 2            Afton Village4         820              0
# 3             Akron Village        2842              1
#
#    Murder and nonnegligent manslaughter  Rape (revised definition)1  \
# 0                                     0                         NaN
# 1                                     0                         NaN
# 2                                     0                         0.0
# 3                                     0                         NaN
#
#    Rape (legacy definition)2  Robbery  Aggravated assault  Property crime  \
# 0                        0.0        0                   0            11.0
# 1                        0.0        1                   1            49.0
# 2                        NaN        0                   0             1.0
# 3                        0.0        0                   1            17.0
#
#    Burglary  Larceny-theft  Motor vehicle theft  Arson3
# 0         1           10.0                    0     0.0
# 1         1           47.0                    1     0.0
# 2         0            1.0                    0     0.0
# 3         0           17.0                    0     0.0

# %%
newdf.isna().sum()
# Out:
# City                                      0
# Population                                0
# Violent crime                             0
# Murder and nonnegligent manslaughter      0
# Rape (revised definition)1              142
# Rape (legacy definition)2               227
# Robbery                                   0
# Aggravated assault                        0
# Property crime                            1
# Burglary                                  0
# Larceny-theft                             1
# Motor vehicle theft                       0
# Arson3                                    4
# dtype: int64

# %%
newdf = df.drop('Rape (revised definition)1',axis=1)
newdf = df.drop('Rape (legacy definition)2',axis=1)

# %%
check=['Population','Violent crime','Murder and nonnegligent manslaughter','Robbery','Aggravated assault','Property crime',
      'Burglary','Larceny-theft','Motor vehicle theft','Arson3']
plt.figure(figsize=(15, 15))
counter=1

for i in check:
    plt.subplot(4,3,counter)
    plt.boxplot(newdf[i], 0, 'rs', 0)
    plt.title(i)
    counter+=1
plt.show()
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1857: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1864: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1872: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1873: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)

# %%
# check the outlier
newdf = newdf.sort_values(by='Population', ascending=False)
newdf.head(5)
# Out:
#           City  Population  Violent crime  \
# 216   New York     8396126          52384
# 35     Buffalo      258789           3249
# 272  Rochester      210562           2107
# 346    Yonkers      199134           1036
# 310   Syracuse      143834           1192
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)1  \
# 216                                   335                         NaN
# 35                                     47                         NaN
# 272                                    42                         NaN
# 346                                     6                         NaN
# 310                                    21                         NaN
#
#      Robbery  Aggravated assault  Property crime  Burglary  Larceny-theft  \
# 216    19170               31767          141971     16606         117931
# 35      1322                1735           12491      3458           8076
# 272      918                1055           10051      2587           6855
# 346      390                 615            2368       470           1662
# 310      400                 696            6473      1781           4298
#
#      Motor vehicle theft  Arson3
# 216                 7434     NaN
# 35                   957     NaN
# 272                  609   132.0
# 346                  236    10.0
# 310                  394    57.0

# %%
newdf = newdf[df['City'] != 'New York']
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
newdf = newdf.sort_values(by='Population', ascending=False)
newdf.head(5)
# Out:
#              City  Population  Violent crime  \
# 35        Buffalo      258789           3249
# 272     Rochester      210562           2107
# 346       Yonkers      199134           1036
# 310      Syracuse      143834           1192
# 7    Amherst Town      118296            107
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)1  \
# 35                                     47                         NaN
# 272                                    42                         NaN
# 346                                     6                         NaN
# 310                                    21                         NaN
# 7                                       1                         NaN
#
#      Robbery  Aggravated assault  Property crime  Burglary  Larceny-theft  \
# 35      1322                1735           12491      3458           8076
# 272      918                1055           10051      2587           6855
# 346      390                 615            2368       470           1662
# 310      400                 696            6473      1781           4298
# 7         31                  68            2118       204           1882
#
#      Motor vehicle theft  Arson3
# 35                   957     NaN
# 272                  609   132.0
# 346                  236    10.0
# 310                  394    57.0
# 7                     32     3.0

# %%
test=newdf
test = test.iloc[1:]

plt.figure(figsize=(15, 15))
counter=1

for i in check:
    plt.subplot(4,3,counter)
    plt.boxplot(test[i], 0, 'rs', 0)
    plt.title(i)
    counter+=1
plt.show()
# Out:
# /home/ll/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:4274: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1857: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1864: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1872: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /home/ll/anaconda3/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:1873: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)

# %%
newdf['Robbery']=newdf['Robbery'] *1.
newdf['Murder and nonnegligent manslaughter']=newdf['Murder and nonnegligent manslaughter'] *1.

# %%
newfeatures = pd.DataFrame()
newfeatures['Population'] = newdf['Population']
newTarget = newdf['Property crime']

regr = linear_model.LinearRegression()
regr.fit(newfeatures, newTarget)
predicted = regr.predict(newfeatures).ravel()
residual = newTarget - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='green')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts (Raw)',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='green')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted (Raw)',fontsize=35)

plt.show()

# %%
rmse = np.sqrt(mean_squared_error(newTarget, predicted))
print('RMSE (Raw):')
print(rmse)
# Out:
# RMSE (Raw):
# 476.444146307

# %%
# log target

# %%
newfeatures['Population'] = np.log(newdf['Population'])


regr = linear_model.LinearRegression()
regr.fit(newfeatures, newTarget)
predicted = regr.predict(newfeatures).ravel()
residual = newTarget - predicted

fig = plt.figure(figsize=(30,30))
ax1 = plt.subplot(211)
sns.distplot(residual, color ='green')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.title('Residual counts (Raw)',fontsize=35)
plt.xlabel('Residual',fontsize=25)
plt.ylabel('Count',fontsize=25)

ax2 = plt.subplot(212)
plt.scatter(predicted, residual, color ='green')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlabel('Predicted',fontsize=25)
plt.ylabel('Residual',fontsize=25)
plt.axhline(y=0)
plt.title('Residual vs. Predicted (Raw)',fontsize=35)

plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(mean_squared_error(newTarget, predicted))
print('RMSE (log):')
print(rmse)
# Out:
# RMSE (log):
# 862.547460559
